# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilo1417/Aula-01-Python/blob/main/Atividade_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sintexe basica

# %%
print("teste \nteste1")
# Out:
# teste
# teste1

# %%
inteiro = 10
inteiro2 = 11
print(inteiro, inteiro2)
# Out:
# 10 11

# %% [markdown]
# String ""

# %%
texto = "11"
print(texto_um)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9361/3520191772.py in <cell line: 0>()
#       1 texto = "11"
# ----> 2 print(texto_um)
#
# NameError: name 'texto_um' is not defined

# %% [markdown]
# Booleano ou Bool

# %%
verdadeiro = True
falso = False
print(verdadeiro, falso)

# %% [markdown]
# Operadores matemático/aritméticos

# %%
soma = 1 + 4
print("soma =", soma)
# Out:
# soma = 5

# %%
subtrair = 8 - 4
print("A subritração é =", subtrair)
# Out:
# A subritração é = 4

# %%
multiplicacao = 8 * 2
print("Multiplicação é =", multiplicacao)
# Out:
# Multiplicação é = 16

# %%
divisao = 8 / 2
print("Divisão é =", divisao)
# Out:
# Divisão é = 4.0

# %%
print("Nome, Joao idade 38 anos  cidade: Brasilia")
# Out:
# Nome, Joao idade 38 anos  cidade: Brasilia

# %% [markdown]
# Atividade 01

# %%
nome = "João Silva"
idade = 25
profissao = "Desenvolvedor"
print ("Seu nome é:",nome)
print("Sua idade é:",idade, "anos")
print("Sua profissão é;", profissao)
# Out:
# Seu nome é: João Silva
# Sua idade é: 25 anos
# Sua profissão é; Desenvolvedor

# %% [markdown]
# Atividade 02

# %%
del print
produto = "Notebook"
marca = "Dell"
preco =  4500.00
print("Produto :", produto)
print("Marca :", marca)
print(f"Preco R$ {preco:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9361/185378022.py in <cell line: 0>()
# ----> 1 del print
#       2 produto = "Notebook"
#       3 marca = "Dell"
#       4 preco =  4500.00
#       5 print("Produto :", produto)
#
# NameError: name 'print' is not defined

# %% [markdown]
# Atividade 3

# %%
num1 = 12
num2 = 6
num3 = 10
soma = num1 + num2 + num3
subtracao = num1 - num2 - num3
mult = num1 * num2 * num3
divisao = int(num1 / num2 / num3)
print("Numero 1:", num1)
print("Numero 2:", num2)
print("Numero 3:", num3)
print("Soma:", soma)
print("Sub:", subtracao)
print("Mult:", mult)
print("Div:", divisao)

# %% [markdown]
# Atividade 04

# %%
from re import sub
num1 = 7
num2 = 2
soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
potenciacao = num1 ** num2
print("Número 1:", num1)
print("Número 2:", num2)
print("Soma:", soma)
print("Subtração:", sub)
print("Multiplicação:", mult)
print("Divisão:", div)
print("Potênciação:", potenciacao)
